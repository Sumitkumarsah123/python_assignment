# %% [markdown]
# # Name: Sumit Kumar Sah
# # Roll: 39
# # Group: CS
# # Assignment-1(python exercise)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %% [markdown]
# # Qn. 1
# A ball is thrown vertically up in the air from a height ho above the ground at an initial velocity vo. Its subsequent height h and velocity 𝑣 are given by the equations.
# $ h=ho+ vot -1/2gt^2 ,$
# $ 𝑣 = 𝑣o −𝑔𝑡 $
# where 𝑔 = 9.8 is the acceleration due to gravity in $𝑚/𝑠^2$.
# Write a script that finds the height h and velocity 𝑣 at a time 𝑡 after the ball is thrown. Start the code by setting ho = 1.2 (meters) and 𝑣o = 5.4 (m/s) and have your code print out the values of height and velocity. Then use the script to find the height and velocity after 0.5 seconds. Then modify your script to find them after 2.0 seconds.

# %% [markdown]
# # Answer

# %%
def height(t, g=9.8,vo=5.4, ho=1.2):# defining a function
    h= ho+ vo*t-1/2*g*t**2
    print("the height at time =" ,h)

def velocity(t, g=9.8, vo=5.4):
    v = vo - g*t
    print("Velocity at time=", v)

# at time 0.5 second   
height(0.5)# calling a function
velocity(0.5)
    
# at time 2.0 second
height(2.0)
velocity(2.0)
# Out:
# the height at time = 2.6750000000000003
# Velocity at time= 0.5
# the height at time = -7.600000000000001
# Velocity at time= -14.200000000000001

# %% [markdown]
# # Qn. 2
#  Write a single Python code that calculates the following expressions:

# %% [markdown]
# a).   $ \frac{2+exp(2.8)}{\sqrt{13}-2} $

# %% [markdown]
# # Answer

# %%
import math
sol1 = (2+ math.exp(2.8))/(math.sqrt(13)-2)
print("the solution of the given expression is   %5.4f " %abs(sol1))
# Out:
# the solution of the given expression is   11.4880

# %% [markdown]
# b). $ \frac{1-(1+\ln(2))^-3.5)}{1+\sqrt(5)} $

# %% [markdown]
# # Answer

# %%
sol2= (1-(1+math.log(2))**-3.5)/(1+math.sqrt(5))
print("the solution of given expression is  %5.4f " % abs(sol2))
# Out:
# the solution of given expression is  0.2601

# %% [markdown]
# c).  $\sin(\frac{2-\sqrt(2)}{2+\sqrt(2)}) $

# %% [markdown]
# # Answer

# %%
sol3= math.sin((2-math.sqrt(2))/(2+math.sqrt(2)))
print("the solution of the given expression is %5.4f " % abs(sol3))
# Out:
# the solution of the given expression is 0.1707

# %% [markdown]
# # Qn.3

# %% [raw]
# Create an array of 9 evenly spaced numbers going from 0 to 29 (inclusive) and give it the variable name 𝑟.
# Find the square of each element of the array (as simply as possible).
# Find twice the value of each element of the array in two different ways:
# (i) using addition and   (ii) using multiplication

# %% [markdown]
# # Answer:

# %%
# creation of 9 spaced evenly number
import numpy as np
r= np.linspace(0,29,9)
r
# Out:
# array([ 0.   ,  3.625,  7.25 , 10.875, 14.5  , 18.125, 21.75 , 25.375,
#        29.   ])

# %%
# square of each element
r**2
# Out:
# array([  0.      ,  13.140625,  52.5625  , 118.265625, 210.25    ,
#        328.515625, 473.0625  , 643.890625, 841.      ])

# %%
# twice of each element :(i)(using addition)
r+r
# Out:
# array([ 0.  ,  7.25, 14.5 , 21.75, 29.  , 36.25, 43.5 , 50.75, 58.  ])

# %%
# twice of each element :(ii)(using multiplaction)
r*2
# Out:
# array([ 0.  ,  7.25, 14.5 , 21.75, 29.  , 36.25, 43.5 , 50.75, 58.  ])

# %% [markdown]
# # Qn. 4

# %% [markdown]
# The position of a ball at time 𝑡 dropped with zero initial velocity from a height ho
# is given by
# $y = ho − 0.5𝑔𝑡^2$
# where 𝑔 = 9.8 𝑚/𝑠
# Suppose ho = 10 𝑚. Find the sequence of times when the ball passes each half meter assuming the ball is dropped at 𝑡 = 0. Hint: Create a NumPy array for y that goes from 10 to 0 in increments of -0.5 using the arrange function.
# Solving the above equation for t, show that
# 𝑡 = $ \frac{\sqrt(2(ho-y))}{g} $
#
# (i) Using this equation and the array you created, find the sequence of times when the ball passes each half meter.
# (ii) Recalling that the average velocity over an interval Δ𝑡 is defined as 𝑣= $\frac{Δ𝑦}{Δ𝑡} $, find the average velocity for each time interval in the problem using NumPy arrays.

# %%
Y = np.arange(10, -0.5, -0.5)
Y
# Out:
# array([10. ,  9.5,  9. ,  8.5,  8. ,  7.5,  7. ,  6.5,  6. ,  5.5,  5. ,
#         4.5,  4. ,  3.5,  3. ,  2.5,  2. ,  1.5,  1. ,  0.5,  0. ])

# %%
'''Sequence of times when ball passes each half meter
   Defining time (t) as a function of height (y)'''

def t(y, g=9.8, h0=10):
 return np.sqrt(2 * (h0 - y) / g)

T = t(Y)
T
# Out:
# array([0.        , 0.31943828, 0.45175395, 0.55328334, 0.63887656,
#        0.71428571, 0.7824608 , 0.84515425, 0.9035079 , 0.95831485,
#        1.01015254, 1.05945693, 1.10656667, 1.15175111, 1.19522861,
#        1.23717915, 1.27775313, 1.31707778, 1.35526185, 1.39239919,
#        1.42857143])

# %%
#Finding average velocity (m/s) on above-mentioned intervals
def avg_velocity(T, Y):
    avg = []
    for t, y in zip(T[:-1], Y[:-1]):
      avg.append((y - Y[np.where(Y==y)[0][0] + 1]) / (T[np.where(T==t)[0][0]+1] - t))
    return avg
avg_velocity(T, Y)
# Out:
# [1.565247584249853,
#  3.778841946367718,
#  4.924682704463059,
#  5.841583510844899,
#  6.6304951684996976,
#  7.334057902536167,
#  7.975313750705891,
#  8.56844457240547,
#  9.122931476985292,
#  9.645490221055367,
#  10.141086409272804,
#  10.613515625657383,
#  11.06575710849935,
#  11.500200609547521,
#  11.91879801222959,
#  12.323168163490518,
#  12.714671457104401,
#  13.094464206458643,
#  13.463539127719816,
#  13.822756041366269]

# %% [markdown]
# # Qn. 5

# %% [markdown]
# Write a program to tell the nature of the roots and values of the roots of a quadratic equation $ 𝑎𝑥^2 +𝑏𝑥 +𝑐 = 0,𝑎 ≠ 0 $.

# %% [markdown]
# # Answer

# %%
import math
def findroot(a,b,c): #defining the function with parameter a,b and c
    if a==0:
        print("invalid, please enter the value greater than 0")
    d= b**2- 4*a*c
    sqrt_val= math.sqrt(abs(d))
    if d>0:
        print("Roots are real and different ") 
        print((-b + sqrt_val)/(2 * a)) 
        print((-b - sqrt_val)/(2 * a)) 
    elif d == 0: 
        print("Roots are real and same") 
        print(-b / (2*a)) 
    else: 
        print("Roots are complex") 
        print(- b / (2*a) , " + i", sqrt_val) 
        print(- b / (2*a) , " - i", sqrt_val) 
  
findroot(2,-1,2)  # calling the function
# Out:
# Roots are complex
# 0.25  + i 3.872983346207417
# 0.25  - i 3.872983346207417

# %% [markdown]
# # Qn. 6

# %% [raw]
#  Write a program to calculate the factorial of a positive integer input by the user.
#  (a) Write the factorial function using a Python while loop.
#  (b) Write the factorial function using a Python for loop.
#  Check your programs to make sure they work for 0,1, 2, 3, 4,5

# %% [markdown]
# # Answer

# %%
#Ans a.
def factorial():
    num= int(input("enter a number: "))
    fac=1
    i=1
    while(i<=num):
        fac = fac * i
        i=i+1
    print("factorial of ", num, " is ", fac)
    
factorial()
# Out:
# enter a number: 5
# factorial of  5  is  120

# %%
# Ans b.
def factorial():
    num= int(input("enter a number: "))
    fac=1
    for i in range(1,num+1):
        fac=fac*i
    print("factorial of ", num, " is ", fac)
factorial()
# Out:
# enter a number: 6
# factorial of  6  is  720

# %% [markdown]
# # Qn.7

# %% [raw]
#  Write a program to calculate the sum of natural n natural numbers 1+2+⋯+𝑛.
#  Calculate the sum when 𝑛 = 10

# %% [markdown]
# # Answer:

# %%
num = int(input("enter the value of n: "))

if num < 0:
   print("Enter a positive number")
else:
   sum = 0
   # use while loop to iterate until zero
   while(num > 0):
       sum += num
       num -= 1
   print("The sum is", sum)
# Out:
# enter the value of n: 10
# The sum is 55

# %% [markdown]
# # Qn.8

# %% [raw]
#  Write a program to calculate the sum of squares of natural n natural numbers 12 +22 + ⋯+𝑛2.
#  Calculate the sum when 𝑛 = 5.

# %% [markdown]
# # Answer:

# %%
def sqr_sum():
    num= int(input("enter the value of n: "))
    
    sum=0
    for i in range(1, num+1):
        sum=sum+i*i
    print("the sum of square of n natural number is ", sum)
sqr_sum()
# Out:
# enter the value of n: 5
# the sum of square of n natural number is  55

# %% [markdown]
# # Qn.9

# %% [markdown]
# Write a program to find the smallest integer n such that $3^n ≥ 2000 $

# %% [markdown]
# # Answer:

# %%
n = 0
while True:
   if (3**n >= 2000): break
   n += 1
n
# Out:
# 7

# %% [markdown]
# # Qn.10

# %% [markdown]
#  Plot the function $𝑦 = 3𝑥^2 $  for −3 ≤ 𝑥 ≤ 3.
#  Include enough points (say 100 points) so that the curve you plot appears smooth.
#  Label the axes x and y.

# %% [markdown]
# # Answer:

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.linspace(-3,3,100)
y= 3*x**2
plt.plot(x,y)
plt.xlabel("x-asis")
plt.ylabel("y-axis")
plt.title("$y=3x^2$");

# %% [markdown]
# # Qn.11

# %% [raw]
#  Plot the functions 𝑦 = 𝑠𝑖𝑛 𝑥 and 𝑦 = 𝑐𝑜𝑠 𝑥 for  −2𝜋 ≤ 𝑥 ≤ 2𝜋 on the same plot.
#  Plot 𝑦 = 𝑠𝑖𝑛 𝑥 in the color red and 𝑦 = 𝑐𝑜𝑠 𝑥 in the color blue and include a legend to label the two curves.
#  Place the legend within the plot, but such that it does not cover either of the sine or cosine traces.

# %% [markdown]
# # Answer:

# %%
x= np.linspace(-2*np.pi, 2*np.pi, 50)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1, color='r')
plt.plot(x,y2, color='b')
plt.legend(['sinx', 'cosx']);

# %% [markdown]
# # Q.n 12

# %% [markdown]
#  Plot the space curve 𝑥 = 2θcos𝜃,𝑦 = 2θsin𝜃,𝑧 = 1+2 𝜃  𝑓𝑜𝑟 0 ≤ 𝜃 ≤ 20𝜋

# %% [markdown]
# # Answer:

# %%
from mpl_toolkits import mplot3d
theta= np.linspace(0, 20*np.pi, 100)
x= 2*theta*np.cos(theta)
y= 2*theta*np.sin(theta)
z= 1+2*theta
fig= plt.figure(figsize=(10,8))
ax= plt.axes(projection= "3d")
ax.plot3D(x,y,z, 'g');
ax.scatter3D(x,y,z);

# %% [markdown]
# # Q.n 13

# %% [markdown]
# Write the program for (i) surface plot (ii) contour plot on 𝑥𝑦 −plane  of the function
# 𝑓(𝑥,𝑦) = $ \frac{1-x/2+ x^5+y^5}{\exp(-x^2-y^2)} $ on the domain $-3<=x<=3 $ and $-3<=y<=3 $.

# %% [markdown]
# # Answer

# %% [markdown]
# # Contour plot

# %%
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
def f(x, y):
     return (1 - (x/2) + x**5 + y**5) / (np.exp((-x**2) - (y**2)))
Z = f(X, Y)

fig = plt.figure(figsize=(10,6))
plt.contourf(X, Y, Z, 10, cmap='magma')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.grid([])

# %% [markdown]
# # Surface plot

# %%
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
def f(x, y):
     return (1 - (x/2) + x**5 + y**5) / (np.exp((-x**2) - (y**2)))
Z = f(X, Y)

fig = plt.figure(figsize=(10,6))
ax = mplot3d.Axes3D(fig);
ax.plot_surface(X, Y, Z, cmap='plasma')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')
